# %% [markdown]
# <a href="https://colab.research.google.com/github/Nayeli4731/RoutesPlanner/blob/main/RoutesPlanner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from pprint import pprint

BASE_URL = 'https://nominatim.openstreetmap.org/search?format=json'


postcode = 'G42 9AY'

response = requests.get(f"{BASE_URL}&postalcode={postcode}")
data = response.json()
print(data)
# Out:
# [{'place_id': 300924595, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'boundingbox': ['55.66523', '55.98523', '-4.4132', '-4.0932'], 'lat': '55.82523', 'lon': '-4.2532', 'display_name': 'G42 9AY', 'class': 'place', 'type': 'postcode', 'importance': 0.325}]

# %%
import requests
from pprint import pprint

#BASE_URL =  'https://nominatim.openstreetmap.org/lookup?osm_ids=W50637691&format=json&extratags=1'
BASE_URL =  'https://nominatim.openstreetmap.org/search?format=json&extratags=1'


postcode = 'G42 9AY'

response = requests.get(f"{BASE_URL}&postalcode={postcode}")
data = response.json()
print(data)
# Out:
# [{'place_id': 300924595, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'boundingbox': ['55.66523', '55.98523', '-4.4132', '-4.0932'], 'lat': '55.82523', 'lon': '-4.2532', 'display_name': 'G42 9AY', 'class': 'place', 'type': 'postcode', 'importance': 0.325, 'extratags': {}}]

# %%
import requests
import json
import folium

BASE_URL = 'https://nominatim.openstreetmap.org/search?format=json&addressdetails=1&extratags=1&namedetails=1'
#BASE_URL = "https://nominatim.openstreetmap.org/details.php?osmtype=W&osmid=38210407&format=json"
class GeoData():

  def fetch(self, address):
    params = { 
        "q": address,
        "format": "geojson"
    }

    res = requests.get(url=BASE_URL, params=params)
    print(f"HTTP GET url {res.url} to {res.status_code}")

    if res.status_code == 200:
      return res
    return None

  def parse(self, res):
    #print(json.dumps(res["features"], indent=2))
    print(res.keys())
    print(json.dumps(res, indent=2))

  def run(self):
    res = self.fetch("Avenida Mariano Otero").json()
    self.parse(res)

  """
 def create_map(self, response):
    # use the response
    mls = response.json()#['features'][0]['geometry']['coordinates']
    points = [(i[1], i[0]) for i in mls[0]]
    m = folium.Map()
    # add marker for the start and ending points
    for point in [points[0], points[-1]]:
        folium.Marker(point).add_to(m)
    # add the lines
    folium.PolyLine(points, weight=5, opacity=1).add_to(m)
    # create optimal zoom
    df = pd.DataFrame(mls[0]).rename(columns={0:'Lon', 1:'Lat'})[['Lat', 'Lon']]
    sw = df[['Lat', 'Lon']].min().values.tolist()
    ne = df[['Lat', 'Lon']].max().values.tolist()
    m.fit_bounds([sw, ne])
    return m
  """


instance = GeoData()
res = instance.run()
#m = instance.create_map(response)
# Out:
# HTTP GET url https://nominatim.openstreetmap.org/search?format=json&addressdetails=1&extratags=1&namedetails=1&q=Avenida+Mariano+Otero&format=geojson to 200
# dict_keys(['type', 'licence', 'features'])
# {
#   "type": "FeatureCollection",
#   "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright",
#   "features": [
#     {
#       "type": "Feature",
#       "properties": {
#         "place_id": 276882421,
#         "osm_type": "way",
#         "osm_id": 910628006,
#         "display_name": "Avenida Mariano Otero, Obreros de la Construcci\u00f3n, Guadalajara, Jalisco, 44550, M\u00e9xico",
#         "place_rank": 26,
#         "category": "highway",
#         "type": "primary",
#         "importance": 0.4,
#         "address": {
#           "road": "Avenida Mariano Otero",
#           "neighbourhood": "Obreros de la Construcci\u00f3n",
#           "city": "Guadalajara",
#           "state": "Jalisco",
#           "ISO3166-2-lvl4": "MX-JAL",
# ...

# %%
pip install xmltodict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import urllib
import time
import requests
import json
import xmltodict

#These variables should be adjusted to meet your requirements, 
#see http://wiki.openstreetmap.org/wiki/API_v0.6#Retrieving_GPS_points for more information

#Boundary Box
min_ln = "98.9311981"
min_lt = "18.7347042"
max_ln = "99.0335083"
max_lt = "18.8309158"

#Start downloading
page = 0 

#Using OSM API V0.6
url = "http://api.openstreetmap.org/api/0.6/trackpoints?bbox="+min_ln+","+min_lt+","+max_ln+","+max_lt+"&page="+str(page)

print (url)

file_prefix = "download_"
file_suffix = ".gpx"
params = { 
    "format": "json"
}
AREA = [min_ln, min_lt, max_ln, max_lt]
#while True:
try:
    file_name = file_prefix+str(page)+file_suffix
    res = requests.get(url)
    if res.status_code == 200:
    #data = res.json()
      dict_data = xmltodict.parse(res.content)
      print(dict_data["gpx"]["trk"][0]["url"])
      print(dict_data["gpx"]["trk"][1]["url"])
      print(dict_data["gpx"]["trk"][2]["url"])
      #print(res.text)
    #print(json.loads(res.text))
    #print(json.dumps(res, indent=2))
except Exception as e:
  print(f"erroooor {e}")
  #print(f"Download stopped; HTTP Error - {e}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9278dc4f7ad0> in <module>
#       3 import requests
#       4 import json
# ----> 5 import xmltodict
#       6
#       7 #These variables should be adjusted to meet your requirements,
#
# ModuleNotFoundError: No module named 'xmltodict'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
